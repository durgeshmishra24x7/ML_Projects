# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#Read Csv file
df = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/carprices.csv')
df.head(3)
# Out:
#   Car Model  Mileage  Sell Price($)  Age(yrs)
# 0    BMW X5    69000          18000         6
# 1    BMW X5    35000          34000         3
# 2    BMW X5    57000          26100         5

# %%
#Plot Scatter graph
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],color='blue')
plt.show()

# %%
#Create Dummy variables
dummies = pd.get_dummies(df['Car Model'])
dummies
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
merged=pd.concat([df,dummies],axis='columns')
merged
# Out:
#                 Car Model  Mileage  ...  BMW X5  Mercedez Benz C class
# 0                  BMW X5    69000  ...       1                      0
# 1                  BMW X5    35000  ...       1                      0
# 2                  BMW X5    57000  ...       1                      0
# 3                  BMW X5    22500  ...       1                      0
# 4                  BMW X5    46000  ...       1                      0
# 5                 Audi A5    59000  ...       0                      0
# 6                 Audi A5    52000  ...       0                      0
# 7                 Audi A5    72000  ...       0                      0
# 8                 Audi A5    91000  ...       0                      0
# 9   Mercedez Benz C class    67000  ...       0                      1
# 10  Mercedez Benz C class    83000  ...       0                      1
# 11  Mercedez Benz C class    79000  ...       0                      1
# ...

# %%
#Drop Text column and any one of Dummy variable to avoid dummy trap
final = merged.drop(['Car Model','Audi A5'],axis='columns')
final
# Out:
#     Mileage  Sell Price($)  Age(yrs)  BMW X5  Mercedez Benz C class
# 0     69000          18000         6       1                      0
# 1     35000          34000         3       1                      0
# 2     57000          26100         5       1                      0
# 3     22500          40000         2       1                      0
# 4     46000          31500         4       1                      0
# 5     59000          29400         5       0                      0
# 6     52000          32000         5       0                      0
# 7     72000          19300         6       0                      0
# 8     91000          12000         8       0                      0
# 9     67000          22000         6       0                      1
# 10    83000          20000         7       0                      1
# 11    79000          21000         7       0                      1
# 12    59000          33000         5       0                      1

# %%
#Create an object for model
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Create Input
X = final.drop('Sell Price($)',axis='columns')
X
# Out:
#     Mileage  Age(yrs)  BMW X5  Mercedez Benz C class
# 0     69000         6       1                      0
# 1     35000         3       1                      0
# 2     57000         5       1                      0
# 3     22500         2       1                      0
# 4     46000         4       1                      0
# 5     59000         5       0                      0
# 6     52000         5       0                      0
# 7     72000         6       0                      0
# 8     91000         8       0                      0
# 9     67000         6       0                      1
# 10    83000         7       0                      1
# 11    79000         7       0                      1
# 12    59000         5       0                      1

# %%
Y = final['Sell Price($)']
Y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
#Train Model
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Make Prediction 
# a) Mileage - 45000, 4 year old,Mercedez Benz 
model.predict([[45000,4,0,1]])
# Out:
# array([36991.31721061])

# %%
# b) Mileage -86000 , 7 year old,BMWX5
model.predict([[86000,7,1,0]])
# Out:
# array([11080.74313219])

# %%
# Accuracy of the model
model.score(X,Y)
# Out:
# 0.9417050937281083
